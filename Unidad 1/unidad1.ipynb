# %%
print(2+2);
# Out:
# 4

# %% [markdown]
# # Datos en Python

# %%
y = 1; # Entero (int)
y = 2.5; # Flotante (float)

# %% [markdown]
# # Operaciones Aritmeticas

# %%
3+5
# Out:
# 8

# %%
3-5
# Out:
# -2

# %%
3*5
# Out:
# 15

# %%
13/5
# Out:
# 2.6

# %%
13 // 5 #?
# Out:
# 2

# %%
13 % 5 # Modulo
# Out:
# 3

# %%
-(-3)
# Out:
# 3

# %%
3**5 # Potencia
# Out:
# 243

# %% [markdown]
# ## Impresion

# %%
print("Hola, soy el numero " + str(y) + " y fui asignado arriba");
# Out:
# Hola, soy el numero 2.5 y fui asignado arriba
